# %%
# Descriptive Statistics


Ans Q1 -

       - Most Representative Value: 12 dozens
It is both the median and the mode, meaning it reflects the center and the most common sales value.
The mean (12.43) is close, but slightly influenced by higher values like 14 and 15.
Since the data is fairly balanced with a slight skew, 12 is a clean and reliable representation of typical daily sales.



Ans Q2-
       - The average performance of the class is about 16 marks.
Most students scored around this value, indicating fairly good overall performance.
Since the scores range from 12 to 20 and are evenly spread, the mean gives a reliable summary of the class.


Ans Q3-
       - The mode tells the most frequently sold shoe size.
 Size 8 is in highest demand, so the store manager should:
Keep more stock of size 8.
Avoid running out of the most popular size.
Plan inventory and purchasing more efficiently.


Ans Q4-
       - If we calculate the mean:=17,740
Most cars are priced between $8,000 and $11,000, but the mean is pulled up by the expensive car.
Median ($10,200) better represents the typical car price.
It is not affected by extreme values (outliers).


Ans Q5-
       - Range = Maximum  Minimum= 40  25 = 15 minutes
        The range shows that the student’s performance is inconsistent to some extent, with noticeable differences in time taken from day to day.


Ans Q6-
        -Range = Maximum- Minimum= 120-98 = 22 kg
        Plan flexible packaging (e.g., not fixed to one exact weight)
Keep extra boxes or storage ready for higher-yield weeks (like 120 kg)
Avoid shortages or wastage during lower-yield weeks (like 98 kg)


Ans Q7-
       - Company A is more consistent.Since 6 < 15, Company As delivery times are closer to the average, meaning delays are more predictable and stable.


Ans Q8-
        -Coin B is more volatile and risky because its prices can rise or fall sharply.
Coin A is more stable, making it relatively safer for investment.


Ans Q9-
        -Mean = 414 kWh
Standard Deviation ≈ 20.6 kWh.
The family typically uses about 414 kWh per month.
The standard deviation (~20.6) is relatively small compared to the mean, meaning:
Their electricity usage is fairly consistent
There are no extreme fluctuations, just normal monthly variation.


Ans Q 10-
   - Mean ≈ 19.63
Median = 19.5
Mode = None
Range = 10
Standard Deviation ≈ 2.87
The player is a reliable and consistent scorer, usually performing around 19-20 points per game with only small fluctuations.
